# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#      Video_id category_id          channel_title  subscriber  \
# 0   HDR9SQc79          22           CaseyNeistat   9086142.0
# 1  KNH52UF?48          24        LastWeekTonight   5937292.0
# 2  QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3  MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4  TWP93KXT70          24               nigahiga  20563106.0
#
#                                                title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  The Trump Presidency: Last Week Tonight with J...
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                   Nickelback Lyrics: Real or Fake?
# 4                           I Dare You: GOING BALD!?
#
#                                                 tags  \
# 0                                    SHANtell martin
# 1  last week tonight trump presidency|last week t...
# 2  racist superman|rudy|mancuso|king|bach|racist|...
# 3  rhett and link|gmm|good mythical morning|rhett...
# ...

# %%
df = df.drop("Unnamed: 17",axis = 1)
df = df.drop("Unnamed: 18",axis = 1)

# %%
df.head()
# Out:
#      Video_id category_id          channel_title  subscriber  \
# 0   HDR9SQc79          22           CaseyNeistat   9086142.0
# 1  KNH52UF?48          24        LastWeekTonight   5937292.0
# 2  QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3  MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4  TWP93KXT70          24               nigahiga  20563106.0
#
#                                                title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  The Trump Presidency: Last Week Tonight with J...
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                   Nickelback Lyrics: Real or Fake?
# 4                           I Dare You: GOING BALD!?
#
#                                                 tags  \
# 0                                    SHANtell martin
# 1  last week tonight trump presidency|last week t...
# 2  racist superman|rudy|mancuso|king|bach|racist|...
# 3  rhett and link|gmm|good mythical morning|rhett...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               3198 non-null   object
#  1   category_id            3192 non-null   object
#  2   channel_title          3195 non-null   object
#  3   subscriber             3175 non-null   float64
#  4   title                  3195 non-null   object
#  5   tags                   3046 non-null   object
#  6   description            3133 non-null   object
#  7   Trend_day_count        3197 non-null   float64
#  8   Tag_count              3197 non-null   object
#  9   Trend_tag_count        3197 non-null   object
#  10  comment_count          3198 non-null   object
#  11  comment_disabled       3198 non-null   object
#  12  like dislike disabled  3198 non-null   object
#  13  likes                  3198 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Video_id                   0
# category_id                6
# channel_title              3
# subscriber                23
# title                      3
# tags                     152
# description               65
# Trend_day_count            1
# Tag_count                  1
# Trend_tag_count            1
# comment_count              0
# comment_disabled           0
# like dislike disabled      0
# likes                      0
# dislike                    0
# tag appered in title       1
# views                      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#      Video_id category_id          channel_title  subscriber  \
# 0   HDR9SQc79          22           CaseyNeistat   9086142.0
# 1  KNH52UF?48          24        LastWeekTonight   5937292.0
# 2  QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3  MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4  TWP93KXT70          24               nigahiga  20563106.0
#
#                                                title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1  The Trump Presidency: Last Week Tonight with J...
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                   Nickelback Lyrics: Real or Fake?
# 4                           I Dare You: GOING BALD!?
#
#                                                 tags  \
# 0                                    SHANtell martin
# 1  last week tonight trump presidency|last week t...
# 2  racist superman|rudy|mancuso|king|bach|racist|...
# 3  rhett and link|gmm|good mythical morning|rhett...
# ...

# %%
df.corr()
# Out:
#                  subscriber  Trend_day_count
# subscriber         1.000000        -0.001535
# Trend_day_count   -0.001535         1.000000

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr())

# %%
f, (ax1) = plt.subplots( figsize=(7, 5), sharex=True)
sns.barplot(x=df["category_id"], y=df["subscriber"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(7, 5), sharex=True)
sns.barplot(x=df["category_id"], y=df["Trend_day_count"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Trend_day_count"], y=df["subscriber"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Tag_count"], y=df["Trend_day_count"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["category_id"], y=df["views"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
df.isnull().sum()
# Out:
# Video_id                 0
# category_id              0
# channel_title            0
# subscriber               0
# title                    0
# tags                     0
# description              0
# Trend_day_count          0
# Tag_count                0
# Trend_tag_count          0
# comment_count            0
# comment_disabled         0
# like dislike disabled    0
# likes                    0
# dislike                  0
# tag appered in title     0
# views                    0
# dtype: int64

# %%
df["views"] = df["views"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2980 entries, 0 to 3196
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               2980 non-null   object
#  1   category_id            2980 non-null   object
#  2   channel_title          2980 non-null   object
#  3   subscriber             2980 non-null   float64
#  4   title                  2980 non-null   object
#  5   tags                   2980 non-null   object
#  6   description            2980 non-null   object
#  7   Trend_day_count        2980 non-null   float64
#  8   Tag_count              2980 non-null   object
#  9   Trend_tag_count        2980 non-null   object
#  10  comment_count          2980 non-null   object
#  11  comment_disabled       2980 non-null   object
#  12  like dislike disabled  2980 non-null   object
#  13  likes                  2980 non-null   object
# ...

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Tag_count"], y=df["subscriber"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Tag_count"], y=df["Trend_day_count"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Trend_tag_count"], y=df["Trend_day_count"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
df["likes"] = df["likes"].astype("int64")
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Trend_tag_count"], y=df["likes"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
df["likes"] = df["likes"].astype("int64")
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Trend_tag_count"], y=df["views"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Tag_count"], y=df["views"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
likeee = df['likes']/100
subsss = df['subscriber']/100
sns.set(rc={'figure.figsize':(10,7)})
sns.lineplot(x = likeee, y = subsss)
# Out:
# <AxesSubplot:xlabel='likes', ylabel='subscriber'>

# %%
sns.set(rc={'figure.figsize':(10,7)})
sns.lineplot(x = df['likes'], y = df['views'])
# Out:
# <AxesSubplot:xlabel='likes', ylabel='views'>

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["Tag_count"], y=df["likes"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %%
f, (ax1) = plt.subplots( figsize=(15, 5), sharex=True)
sns.barplot(x=df["category_id"], y=df["likes"], palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)
